# %% [markdown]
# <a href="https://colab.research.google.com/github/Sony17/self-driving-car/blob/main/DeepNueralNetwork.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam

# %%
np.random.seed(0)
n_pts = 500
X, y = datasets.make_circles(n_samples=n_pts, random_state = 123, noise=0.1, factor=0.2)
# print(X) 
# print(y)
 
plt.scatter(X[y==0, 0], X[y==0, 1])
plt.scatter(X[y==1, 0], X[y==1, 1])

# %%
model = Sequential()
model.add(Dense(4, input_shape=(2,), activation='sigmoid'))
model.add(Dense(1, activation='sigmoid'))
model.compile(Adam(lr = 0.01), 'binary_crossentropy', metrics=['accuracy'])
h = model.fit(x= X,y=y, verbose=1,batch_size=20,epochs= 100, shuffle='true')
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# Epoch 1/100
# 25/25 [==============================] - 14s 1ms/step - loss: 0.6966 - accuracy: 0.4483
# Epoch 2/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.6957 - accuracy: 0.4452
# Epoch 3/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.6942 - accuracy: 0.4995
# Epoch 4/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.6937 - accuracy: 0.4491
# Epoch 5/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.6937 - accuracy: 0.6384
# Epoch 6/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.6924 - accuracy: 0.6438
# Epoch 7/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.6938 - accuracy: 0.4323
# Epoch 8/100
# ...

# %%
plt.plot(h.history['accuracy'])
plt.legend(['accuracy'])
plt.ylabel('accuracy')
plt.xlabel('epoch')
# Out:
# Text(0.5, 0, 'epoch')

# %%
plt.plot(h.history['loss'])
plt.legend(['loss'])
plt.title('loss')
plt.xlabel('epoch')
# Out:
# Text(0.5, 0, 'epoch')

# %%
def plot_decision_boundary(X, y, model):
    x_span = np.linspace(min(X[:,0]) - 0.25, max(X[:,0]) + 0.25)
    y_span = np.linspace(min(X[:,1]) - 0.25, max(X[:,1]) + 0.25)
    xx, yy = np.meshgrid(x_span, y_span)
    grid = np.c_[xx.ravel(), yy.ravel()]
    pred_func = model.predict(grid)
    z = pred_func.reshape(xx.shape)
    plt.contourf(xx, yy, z)

# %%
plot_decision_boundary(X, y, model)

# %%
plot_decision_boundary(X, y, model)
plt.scatter(X[:n_pts,0],X[:n_pts,1])
plt.scatter(X[n_pts:,0],X[n_pts:,1])

# %%
# plt.scatter(X[y==0, 0], X[y==0, 1])
# plt.scatter(X[y==1, 0], X[y==1, 1])
# plot_decision_boundary(X, y, model)
# plt.scatter(X[y==0, 0], X[y==0, 1])
# plt.scatter(X[y==1, 0], X[y==1, 1])
plot_decision_boundary(X, y, model)
plt.scatter(X[:n_pts,0],X[:n_pts,1])
plt.scatter(X[n_pts:,0],X[n_pts:,1])

x = 0
y = 0.3
 
point = np.array([[x, y]])
predict = model.predict(point)
plt.plot([x], [y], marker='o', markersize=10, color="red")
print("Prediction is: ", predict)
# Out:
# Prediction is:  [[0.9724985]]
